# %% [markdown]
# # Skylytics — Step 01: Data Acquisition
#
# Download/locate all raw data sources: BTS (2015 + post-2015), Meteostat weather, OpenFlights metadata.
#
# > **Roadmap:** See SKYLYTICS_MODEL_ROADMAP.md for full specification.

# %%
# TODO: Implement this notebook per the roadmap specification
# See SKYLYTICS_MODEL_ROADMAP.md → Step 01: Data Acquisition
